# %%
import networkx as nx

# %%
G = nx.DiGraph()
edges = [(1, 2), (2, 3), (2, 1), (3, 2), (3, 4), (4, 1), (4, 2)]
G.add_edges_from(edges)

# %%
hm = nx.pagerank(G, alpha=0.15)

# %%
print(hm)
# Out:
# {1: 0.25112527136230467, 2: 0.28496212579345703, 3: 0.23387222283935546, 4: 0.2300403800048828}
